# %% [markdown]
# # IMPORTING USEFUL LIBRARIES AND DATASETS

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px
from datetime import datetime, date, timedelta
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/brazilian-ecommerce/olist_sellers_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_customers_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_orders_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_products_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_order_payments_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_geolocation_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_order_reviews_dataset.csv
# /kaggle/input/brazilian-ecommerce/olist_order_items_dataset.csv
# /kaggle/input/brazilian-ecommerce/product_category_name_translation.csv
# /kaggle/input/marketing-funnel-olist/olist_closed_deals_dataset.csv
# /kaggle/input/marketing-funnel-olist/olist_marketing_qualified_leads_dataset.csv

# %% [markdown]
# <h1>INTRODUCTION</h1>
# Hello, we are researchers at the Mauá Technology Institute, in Brazil. In this project we will present some objectives that were defined from the crossing of two datasets provided by Olist Store.<br>
#
#
# by [Gabriel Lima](http://https://github.com/GabrielLima1995),  [Giovanni Schiffini](https://github.com/schiffini), [Marcio Oliverio](https://github.com/oliverra), [Michelle Alves](https://github.com/MichelleAlves84) e Rafael Brayner Costa.
#
#
#
# <h1>WHAT IS OLIST?</h1>
# Olist is a SaaS (Software as a Service) technology company founded in 2015 that offers a solution to increase sales for retailers of all sizes, for most segments, whether they have an online presence or not.
#
# Olist operates in the e-commerce segment, but it is not e-commerce itself. Olist is a large department store within the marketplaces, formed by thousands of other stores throughout Brazil.
#
# This store is already connected to the main e-commerces in Brazil and offers these privileged spaces so that the participants can advertise their products to the e-commerces visitors.
#
# <h1>COLLECTING INFORMATION ABOUT OLIST</h1>
# This study used the datasets:
#
# *Marketing Funnel:* dataset with information from 8 thousand Marketing Qualified Leads (MQLs) who requested contact with Olist between June 1, 2017 and June 1, 2018. This dataset shows the sales process in multiple dimensions: lead category, catalog size, behavior profile, etc.
#
# *Brazilian E-Commerce Public Dataset:* dataset with information on 100 thousand orders from 2016 to 2018 placed in different markets in Brazil. Its features allow the viewing of an order in multiple dimensions: from order status, price, payment and shipping performance to the customer's location, product attributes and, finally, written reviews by customers. There is also a set of geolocation data that relates Brazilian postal codes to lat / lng coordinates.
#
# All data exposed in these two datasets are real and have been made anonymous and sampled from the original data set.

# %% [markdown]
# [](http://)<h1>OBJECTIVE</h1>

# %% [markdown]
# Find the best represetant for each deal! For this, probably you will have to create a model capable of using the information from the seller_id in the Brazillian OList ECommerce database to characterize each particular seller, and their products, to finally find the best cluster of representants to use in a particular client/seller.

# %% [markdown]
# Importing Dataset

# %%
marketing_qualified_leads = pd.read_csv("/kaggle/input/marketing-funnel-olist/olist_marketing_qualified_leads_dataset.csv")
closed_deals_dataset      = pd.read_csv("/kaggle/input/marketing-funnel-olist/olist_closed_deals_dataset.csv")
order_itens_dataset       = pd.read_csv("/kaggle/input/brazilian-ecommerce/olist_order_items_dataset.csv")
df_products               = pd.read_csv("/kaggle/input/brazilian-ecommerce/olist_products_dataset.csv")

# %% [markdown]
# Checking the headers of each dataset

# %%
marketing_qualified_leads.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
closed_deals_dataset.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#                              sdr_id                             sr_id  \
# 0  a8387c01a09e99ce014107505b92388c  4ef15afb4b2723d8f3d81e51ec7afefe
# 1  09285259593c61296eef10c734121d5b  d3d1e91a157ea7f90548eef82f1955e3
# 2  b90f87164b5f8c2cfa5c8572834dbe3f  6565aa9ce3178a5caf6171827af3a9ba
# 3  56bf83c4bb35763a51c2baab501b4c67  d3d1e91a157ea7f90548eef82f1955e3
# 4  4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
#
#               won_date business_segment      lead_type lead_behaviour_profile  \
# 0  2018-02-26 19:58:54              pet  online_medium                    cat
# 1  2018-05-08 20:17:59  car_accessories       industry                  eagle
# 2  2018-06-05 17:27:23  home_appliances     online_big                    cat
# 3  2018-01-17 13:51:03       food_drink   online_small                    NaN
# 4  2018-07-03 20:17:45  home_appliances       industry                   wolf
#
#   has_company has_gtin average_stock business_type  \
# 0         NaN      NaN           NaN      reseller
# 1         NaN      NaN           NaN      reseller
# 2         NaN      NaN           NaN      reseller
# 3         NaN      NaN           NaN      reseller
# 4         NaN      NaN           NaN  manufacturer
#
#    declared_product_catalog_size  declared_monthly_revenue
# 0                            NaN                       0.0
# 1                            NaN                       0.0
# 2                            NaN                       0.0
# 3                            NaN                       0.0
# 4                            NaN                       0.0

# %%
order_itens_dataset.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
df_funnel = marketing_qualified_leads.merge(closed_deals_dataset, on='mql_id', how='left')

# %%
df_funnel.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin  \
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search
#
#                           seller_id                            sdr_id  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
#
#                               sr_id             won_date business_segment  \
# 0                               NaN                  NaN              NaN
# 1                               NaN                  NaN              NaN
# 2                               NaN                  NaN              NaN
# 3                               NaN                  NaN              NaN
# 4  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
#
#        lead_type lead_behaviour_profile has_company has_gtin average_stock  \
# 0            NaN                    NaN         NaN      NaN           NaN
# 1            NaN                    NaN         NaN      NaN           NaN
# 2            NaN                    NaN         NaN      NaN           NaN
# 3            NaN                    NaN         NaN      NaN           NaN
# 4  online_medium                    cat         NaN      NaN           NaN
#
#   business_type  declared_product_catalog_size  declared_monthly_revenue
# 0           NaN                            NaN                       NaN
# 1           NaN                            NaN                       NaN
# 2           NaN                            NaN                       NaN
# 3           NaN                            NaN                       NaN
# 4      reseller                            NaN                       0.0

# %% [markdown]
# # <b>UNDERSTANDING THE DATA</b>

# %% [markdown]
# Olist Dataset Schema

# %% [markdown]
# ![](https://i.imgur.com/HRhd2Y0.png)

# %% [markdown]
# Marketing Funnel Dataset Schema

# %% [markdown]
# ![](https://i.imgur.com/Jory0O3.png)

# %% [markdown]
# # DESCRIPTION OF THE COLUMNS

# %% [markdown]
# **marketing_qualified_leads**</p>
# *Columns | mql_id	| first_contact_date | landing_page_id | origin*
# <p></p>
# <p>mql_id : Marketing Qualified Lead id </p>
# <p>first_contact_date : Date of first contact between seller and customer  </p>
# <p>landing_page_ID : Landing page id where the lead was acquired  </p>
# <p>origin : Type of media where the lead was acquired </p>

# %% [markdown]
# **closed_deals_dataset**</p>
# *Columns | mql_id |	seller_id | sdr_id |	sr_id |	won_date  |	business_segment  |	lead_type |	lead_behaviour_profile |	has_company |	has_gtin  |	average_stock |	business_type |	declared_product_catalog_size	| declared_monthly_revenue*
# <p></p>
#
#
# <p>mql_id : Marketing Qualified Lead ID</p>
# <p>seller_id : Seller ID  </p>
# <p>sdr_id: Sales development Representative ID </p>
# <p>sr_id: Sales Representative ID </p>
# <p>won_date: Date the deal was closed </p>
# <p>business_segment: Lead business segment (Informed on contact) </p>
# <p>lead_type: Lead type (Informed on contact) </p>
# <p>lead_behaviour_profile : Lead behaviour profile (SDR identify it on contact)</p>
# <p>has_company: Does the lead have a company (formal documentation)? </p>
# <p>has_gtin: Does the lead have Global Trade Item Number (barcode) for his products? </p>
# <p>average_stock: Lead declared average stock (Informed on contact) </p>
# <p>business_type: Type of business (reseller/manufacturer etc.) </p>
# <p>declared_product_catalog_size: Lead declared catalog size (Informed on contact) </p>
# <p>declared_monthly_revenue: Lead declared estimated monthly revenue (Informed on contact)  </p>

# %% [markdown]
# **order_itens_dataset**</p>
# *Columns | order_id | order_item_id | product_id | seller_id | shipping_limit_date | price | freight_value*
# <p></p>
#
#
# <p>order_id: sequential number identifying number of items included in the same order </p>
# <p>product_id: Product unique identifier</p>
# <p>seller_id: Seller unique identifier</p>
# <p>shipping_limit_date: Shows the seller shipping limit date for handling the order over to the logistic partner</p>
# <p>price: Item price </p>
# <p>freight_value: Item freight value item (if an order has more than one item the freight value is splitted between items) </p>

# %% [markdown]
# **df_funnel** </p>
#
# Merge between *marketing_qualified_leads* and *closed_deals_dataset*
# <p></p>

# %% [markdown]
# # ANALYSING THE DATA

# %% [markdown]
# Merging the *order_itens_dataset* from *seller_id*. The "left" method inserts the new data at the last columns. The *product_id* has been dropped because it was already at the dataframe.

# %%
df_funnel_items = df_funnel.dropna(subset=["seller_id"]).merge(order_itens_dataset, on='seller_id', how='left')
df_funnel_items = df_funnel_items.dropna(subset=["product_id"])

# %%
df_funnel_items.head()
# Out:
#                              mql_id first_contact_date  \
# 0  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 1  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 2  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 4  327174d3648a2d047e8940d7d15204ca         2018-04-03
# 5  327174d3648a2d047e8940d7d15204ca         2018-04-03
#
#                     landing_page_id          origin  \
# 0  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 1  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 2  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 4  1ceb590cd1e00c7ee95220971f82693d  organic_search
# 5  1ceb590cd1e00c7ee95220971f82693d  organic_search
#
#                           seller_id                            sdr_id  \
# 0  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
# 1  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
# 2  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
# 4  612170e34b97004b3ba37eae81836b4c  b90f87164b5f8c2cfa5c8572834dbe3f
# 5  612170e34b97004b3ba37eae81836b4c  b90f87164b5f8c2cfa5c8572834dbe3f
#
#                               sr_id             won_date business_segment  \
# 0  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
# 1  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
# 2  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
# 4  6565aa9ce3178a5caf6171827af3a9ba  2018-06-05 17:27:23  home_appliances
# 5  6565aa9ce3178a5caf6171827af3a9ba  2018-06-05 17:27:23  home_appliances
#
#        lead_type  ... average_stock business_type  \
# 0  online_medium  ...           NaN      reseller
# 1  online_medium  ...           NaN      reseller
# 2  online_medium  ...           NaN      reseller
# 4     online_big  ...           NaN      reseller
# 5     online_big  ...           NaN      reseller
#
#   declared_product_catalog_size declared_monthly_revenue  \
# 0                           NaN                      0.0
# 1                           NaN                      0.0
# 2                           NaN                      0.0
# 4                           NaN                      0.0
# 5                           NaN                      0.0
#
#                            order_id  order_item_id  \
# 0  1efcc6ba75b519535a510c53153a9256            1.0
# 1  d8d281c1a1398a1e835fdc4adfb81e2a            1.0
# 2  e5858127da61f07285827883e605254b            1.0
# 4  0475d054d40280dfba750663c9ad7a0a            1.0
# 5  05104976125ea1e5cc04bc1f506a436a            1.0
#
#                          product_id  shipping_limit_date  price freight_value
# 0  e94df75b2e9a8b056be0c144a731f55c  2018-06-26 22:20:21   94.2         18.76
# 1  9e0873e9ac04b12f282b81af5daebd2e  2018-07-30 09:31:49  664.0         38.41
# 2  9bb2d066e4b33b624cbdfec7d50b3dcb  2018-06-27 16:00:04   99.8         15.00
# 4  a86859b91d632c991b914aead6ec8ad4  2018-08-07 17:35:18   49.9         13.69
# 5  63bfa27a0cee21fd896dc27f58b6d656  2018-08-19 22:44:03  198.9         18.32
#
# [5 rows x 23 columns]

# %% [markdown]
# Now, the *df_products* dataset is merged from the *product_id* column, again attaching its columns to the last positions.

# %%
df_funnel_products = df_funnel_items.merge(df_products, on="product_id", how="left")

# %%
df_funnel_products.head()
# Out:
#                              mql_id first_contact_date  \
# 0  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 1  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 2  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 3  327174d3648a2d047e8940d7d15204ca         2018-04-03
# 4  327174d3648a2d047e8940d7d15204ca         2018-04-03
#
#                     landing_page_id          origin  \
# 0  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 1  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 2  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 3  1ceb590cd1e00c7ee95220971f82693d  organic_search
# 4  1ceb590cd1e00c7ee95220971f82693d  organic_search
#
#                           seller_id                            sdr_id  \
# 0  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
# 1  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
# 2  2c43fb513632d29b3b58df74816f1b06  a8387c01a09e99ce014107505b92388c
# 3  612170e34b97004b3ba37eae81836b4c  b90f87164b5f8c2cfa5c8572834dbe3f
# 4  612170e34b97004b3ba37eae81836b4c  b90f87164b5f8c2cfa5c8572834dbe3f
#
#                               sr_id             won_date business_segment  \
# 0  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
# 1  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
# 2  4ef15afb4b2723d8f3d81e51ec7afefe  2018-02-26 19:58:54              pet
# 3  6565aa9ce3178a5caf6171827af3a9ba  2018-06-05 17:27:23  home_appliances
# 4  6565aa9ce3178a5caf6171827af3a9ba  2018-06-05 17:27:23  home_appliances
#
#        lead_type  ...  price freight_value    product_category_name  \
# 0  online_medium  ...   94.2         18.76                 pet_shop
# 1  online_medium  ...  664.0         38.41       ferramentas_jardim
# 2  online_medium  ...   99.8         15.00                 pet_shop
# 3     online_big  ...   49.9         13.69  sinalizacao_e_seguranca
# 4     online_big  ...  198.9         18.32              eletronicos
#
#   product_name_lenght product_description_lenght  product_photos_qty  \
# 0                56.0                     1538.0                 2.0
# 1                25.0                      432.0                 1.0
# 2                53.0                     1494.0                 2.0
# 3                60.0                     1170.0                 1.0
# 4                59.0                      600.0                 6.0
#
#    product_weight_g product_length_cm  product_height_cm product_width_cm
# 0             625.0              23.0               17.0             19.0
# 1            2825.0              29.0               29.0             29.0
# 2             900.0              26.0               19.0             23.0
# 3             450.0              16.0                5.0             16.0
# 4             475.0              20.0               11.0             19.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Changing the *won_date* (deal closing date) to a timestamp, using the datetime library. This action makes it easy to order and filter by date.

# %%
df_funnel_products['won_date'][0]
# Out:
# '2018-02-26 19:58:54'

# %%
df_funnel_products["won_date"] = df_funnel_products["won_date"].apply(lambda d: datetime.strptime(d,"%Y-%m-%d %H:%M:%S"))

# %%
df_funnel_products['won_date'][0]
# Out:
# Timestamp('2018-02-26 19:58:54')

# %% [markdown]
# Now, the *first_contact_date* will be transformed into a timestamp.

# %%
df_funnel_products["first_contact_date"] = df_funnel_products["first_contact_date"].apply(lambda d: datetime.strptime(d,"%Y-%m-%d"))

# %%
df_funnel_products.seller_id.unique().shape[0]
# Out:
# 380

# %% [markdown]
# As we can see above, the dataframe has 380 unique seller ids, so, 380 individual sellers are represented in this dataframe.

# %%
df_funnel_products.business_segment.unique()
# Out:
# array(['pet', 'home_appliances', 'health_beauty', 'household_utilities',
#        'construction_tools_house_garden', 'sports_leisure', 'food_drink',
#        'home_decor', 'watches', 'computers', 'small_appliances',
#        'audio_video_electronics', 'bed_bath_table', 'car_accessories',
#        'home_office_furniture', 'books', 'party', 'air_conditioning',
#        'phone_mobile', 'music_instruments', 'baby', 'handcrafted',
#        'fashion_accessories', 'toys', 'bags_backpacks', 'stationery',
#        'food_supplement', 'gifts', 'games_consoles'], dtype=object)

# %% [markdown]
# There are 28 business segments in this dataframe.

# %% [markdown]
# Using the *plotly* library, the following chart shows the main business segments on the OList Brazilian ecommerce.

# %%
analisys  = df_funnel_products.business_segment.value_counts()

# %%
fig = px.pie(values=analisys, names=analisys.index, title='Most common business segments ')
fig.show()
# Out:
# <div>                            <div id="b6bfb69d-8dcb-4414-a983-b2d3ac717449" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6bfb69d-8dcb-4414-a983-b2d3ac717449")) {                    Plotly.newPlot(                        "b6bfb69d-8dcb-4414-a983-b2d3ac717449",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["health_beauty", "watches", "household_utilities", "home_decor", "construction_tools_house_garden", "pet", "audio_video_electronics", "bed_bath_table", "sports_leisure", "car_accessories", "home_appliances", "bags_backpacks", "computers", "toys", "books", "food_supplement", "home_office_furniture", "small_appliances", "stationery", "fashion_accessories", "phone_mobile", "food_drink", "baby", "music_instruments", "handcrafted", "gifts", "air_conditioning", "games_consoles", "party"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [821, 594, 561, 452, 318, 286, 275, 188, 179, 164, 141, 140, 125, 121, 106, 100, 82, 69, 60, 60, 56, 49, 42, 25, 11, 8, 4, 4, 3]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222222222222 ...

# %% [markdown]
# Since *health and beauty* is the most relevant business segment, we are going to look specifically at its data:

# %% [markdown]
# # **A close look at the 'Health and beauty' business segment**

# %%
health_beauty = df_funnel_products.where(df_funnel_products['business_segment'] == 'health_beauty').dropna(subset=["seller_id"])

# %%
health_beauty.seller_id.unique().shape[0]
# Out:
# 45

# %% [markdown]
# Selecting specifically the *health_beauty* business segment with the 'dropna' pandas funcion, there are only 45 sellers.

# %% [markdown]
# # Sales representative with the most sales:

# %%
fig = px.histogram(health_beauty.seller_id, x="seller_id").update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <div>                            <div id="61969b38-48df-4ff0-85af-91f12e05ded6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61969b38-48df-4ff0-85af-91f12e05ded6")) {                    Plotly.newPlot(                        "61969b38-48df-4ff0-85af-91f12e05ded6",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "seller_id=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["1c742ac33582852aaf3bcfbf5893abcf", "44ed138eca6214d572ce1d813fb0049b", "44ed138eca6214d572ce1d813fb0049b", "44ed138eca6214d572ce1d813fb0049b", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "b494891378bd8f4560abe576c52deacd", "8b181ee5518df84f18f4e1a43fe07923", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "ca4b77513ac2040591b0d8fae6958380", "e9e446d01bd10a97a8ffcfc4a3a20cb2", "e9e446d01bd10a97a8ffcfc4a3a20cb2", "e9e446d01bd10a97a8ffcfc4a3a20cb2", "e9e446d01bd10a97a8ffcfc4a3a20cb2", "a7d0f8dd44f57ef6de7f7f02e3d82630", "a7d0f8dd44f57ef6de7f7f02e3d82630", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "3d5d0dc7073a299e31fa718ce1bc00b6", "a69aa24cec11168e7e39a3fbc727e925", "a69aa24cec11168e7e39a3fbc727e925", "a69aa24cec11168e7e39a3fbc727e925", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "c54679b132454625907c773d273d4126", "4a82168aaef173cbb6e46ae88728f919", "4a82168aaef173cbb6e46ae88728f919", "4a82168aaef173cbb6e46ae88728f919", "4a82168aaef173cbb6e46ae88728f919", "6aa3928696eab49a19a466e665a649fd", "6aa3928696eab49a19a466e665a649fd", "6aa392 ...

# %% [markdown]
# Three sales representatives are responsible for most of the deals in this segment, specially the first one. This could be one method to determine which is the best seller representative, but other methods are showed on the next steps.

# %% [markdown]
# Down below, the list of all sellers in this segment and their *first_contact_date*.

# %%
health_beauty_init_date    = health_beauty.groupby(by = 'seller_id').min()['first_contact_date']
health_beauty_oldest_seller= health_beauty_init_date.sort_values(axis=0, ascending=True)
health_beauty_oldest_seller
# Out:
# seller_id
# 89a51f50b8095ea78d5768f34c13a76f   2017-08-30
# 4a82168aaef173cbb6e46ae88728f919   2017-12-26
# c54679b132454625907c773d273d4126   2018-01-03
# bd4431c1a8dfa744b59e1e2a8bc99b9e   2018-01-03
# 4867209cb29b56b92893d7bde3ce8012   2018-01-11
# e116c7455dd26a4d8c3e92532583905f   2018-01-12
# 2fa13c8bd5705d279f7ed5cc9ec61c68   2018-01-12
# 0b1ca3ef18a63d7eb0c8897fa0849c08   2018-01-17
# dace965ca58120f92f8d742a9fa1864b   2018-01-20
# ae45df84722b1d15c5f32b23a095746c   2018-01-24
# dbdd0ec73a4817971d962698f2fea022   2018-01-24
# 6aa3928696eab49a19a466e665a649fd   2018-02-02
# 1c742ac33582852aaf3bcfbf5893abcf   2018-02-06
# 4a23adac87cf538689fa600d976f78b2   2018-02-07
# 6bd503a8230299c9316fb0f726933927   2018-02-10
# ca7c6bd577e559472af1c699de9e764e   2018-02-16
# 2e7ea2aafec5835e781b21d6d1faf1f1   2018-02-22
# 28c7d8743fbc8679f484868cc0fcaefb   2018-02-22
# f22a247b79dd22ecd91dc8e3b2a1b07c   2018-02-23
# 4f0d637c1197fd65405ebd755ac9f86b   2018-02-28
# 094ced053e257ae8cae57205592d6712   2018-03-02
# a69aa24cec11168e7e39a3fbc727e925   2018-03-06
# 5e063e85d44b0f5c3e6ec3131103a57e   2018-03-08
# c70c1b0d8ca86052f45a432a38b73958   2018-03-13
# 698f5fa55a5f73d0740e9d9a773e8093   2018-03-14
# 5670f4db5b62c43d542e1b2d56b0cf7c   2018-03-20
# 6ebf4eceee4dd9847201c82e77ef8123   2018-03-20
# 8b181ee5518df84f18f4e1a43fe07923   2018-03-22
# 53088c75f948b48a7ece173ac17f0c12   2018-03-28
# e9e446d01bd10a97a8ffcfc4a3a20cb2   2018-04-04
# f46490624488d3ff7ce78613913a7711   2018-04-04
# ca4b77513ac2040591b0d8fae6958380   2018-04-06
# c70a353f02429c00775a46a75fb787da   2018-04-08
# 2c2c9832d1bb38c5b0034a3b47d313ee   2018-04-10
# 44ed138eca6214d572ce1d813fb0049b   2018-04-13
# 85ecf03781da592876b7844acc1b729f   2018-04-17
# 985c92cc412091f8529c12d7f23d3fef   2018-04-18
# 1cbd32d00d01bb8087a5eb088612fd9c   2018-04-19
# 3d5d0dc7073a299e31fa718ce1bc00b6   2018-04-20
# a7d0f8dd44f57ef6de7f7f02e3d82630   2018-04-26
# eb72802c83dc7547529c9546d1a9b8ef   2018-04-28
# 516e7738bd8f735ac19a010ee5450d8d   2018-05-02
# ce4755084bc097113867e6454f8f5e52   2018-05-07
# a63bfbaa882c8f4542891b4e2246cc7f   2018-05-22
# b494891378bd8f4560abe576c52deacd   2018-05-24
# Name: first_contact_date, dtype: datetime64[ns]

# %% [markdown]
# # Mean sales per day for each sales representative:

# %% [markdown]
# Grouping the sellers by its *won_date*.

# %%
health_beauty_won_date_max= health_beauty.groupby(by = 'seller_id').max()['won_date']

# %% [markdown]
# Subtracting the *initial date* from the *won date*, to determine how long it took, in average, to close a deal.

# %%
health_beauty_days_sellers = (health_beauty_won_date_max-health_beauty_init_date).apply(lambda d: d.days).to_frame(name='days_')

# %% [markdown]
# Counting the transactions on this business segment.

# %%
health_beauty_count = health_beauty.groupby(by = 'seller_id').count()['mql_id'].to_frame(name ='count')

# %% [markdown]
# Merging the sellers to the total transaction count dataframe.

# %%
health_beauty_days_sellers = health_beauty_days_sellers.merge(health_beauty_count, on='seller_id', how='left')

# %% [markdown]
# Obtaining the mean sales per day for each seller id.

# %%
health_beauty_days_sellers['mean'] = health_beauty_days_sellers['count'] /health_beauty_days_sellers['days_']

# %%
health_beauty_days_sellers.sort_values(axis=0, ascending=False,by='mean')
# Out:
#                                   days_  count       mean
# seller_id
# c70c1b0d8ca86052f45a432a38b73958      0    338        inf
# 985c92cc412091f8529c12d7f23d3fef      0     12        inf
# 516e7738bd8f735ac19a010ee5450d8d      6     84  14.000000
# 698f5fa55a5f73d0740e9d9a773e8093      1      6   6.000000
# 6aa3928696eab49a19a466e665a649fd      5     22   4.400000
# eb72802c83dc7547529c9546d1a9b8ef      2      8   4.000000
# 5670f4db5b62c43d542e1b2d56b0cf7c      6     22   3.666667
# a63bfbaa882c8f4542891b4e2246cc7f      2      7   3.500000
# f46490624488d3ff7ce78613913a7711     42     91   2.166667
# ae45df84722b1d15c5f32b23a095746c      6     12   2.000000
# a7d0f8dd44f57ef6de7f7f02e3d82630      1      2   2.000000
# dbdd0ec73a4817971d962698f2fea022      9     16   1.777778
# 094ced053e257ae8cae57205592d6712     11     19   1.727273
# c54679b132454625907c773d273d4126      5      8   1.600000
# 3d5d0dc7073a299e31fa718ce1bc00b6     17     24   1.411765
# 1c742ac33582852aaf3bcfbf5893abcf      1      1   1.000000
# ce4755084bc097113867e6454f8f5e52      1      1   1.000000
# 1cbd32d00d01bb8087a5eb088612fd9c     13     12   0.923077
# b494891378bd8f4560abe576c52deacd     26     22   0.846154
# dace965ca58120f92f8d742a9fa1864b     10      8   0.800000
# 44ed138eca6214d572ce1d813fb0049b      4      3   0.750000
# 2fa13c8bd5705d279f7ed5cc9ec61c68      6      4   0.666667
# c70a353f02429c00775a46a75fb787da     12      6   0.500000
# 2c2c9832d1bb38c5b0034a3b47d313ee      3      1   0.333333
# bd4431c1a8dfa744b59e1e2a8bc99b9e     23      7   0.304348
# ca7c6bd577e559472af1c699de9e764e     27      8   0.296296
# ca4b77513ac2040591b0d8fae6958380     66     15   0.227273
# e116c7455dd26a4d8c3e92532583905f     10      2   0.200000
# e9e446d01bd10a97a8ffcfc4a3a20cb2     23      4   0.173913
# 4f0d637c1197fd65405ebd755ac9f86b     12      2   0.166667
# 85ecf03781da592876b7844acc1b729f     13      2   0.153846
# f22a247b79dd22ecd91dc8e3b2a1b07c     54      8   0.148148
# 6ebf4eceee4dd9847201c82e77ef8123      7      1   0.142857
# 28c7d8743fbc8679f484868cc0fcaefb     29      3   0.103448
# 0b1ca3ef18a63d7eb0c8897fa0849c08     12      1   0.083333
# 2e7ea2aafec5835e781b21d6d1faf1f1     88      7   0.079545
# 53088c75f948b48a7ece173ac17f0c12     42      3   0.071429
# 4867209cb29b56b92893d7bde3ce8012     18      1   0.055556
# a69aa24cec11168e7e39a3fbc727e925     55      3   0.054545
# 6bd503a8230299c9316fb0f726933927    100      5   0.050000
# 89a51f50b8095ea78d5768f34c13a76f    223     11   0.049327
# 4a82168aaef173cbb6e46ae88728f919    127      4   0.031496
# 8b181ee5518df84f18f4e1a43fe07923     34      1   0.029412
# 4a23adac87cf538689fa600d976f78b2    162      3   0.018519
# 5e063e85d44b0f5c3e6ec3131103a57e     -2      1  -0.500000

# %%
fig = px.bar(health_beauty_days_sellers['mean'], x=health_beauty_days_sellers.index, y=['mean']).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <div>                            <div id="85934564-7a2e-480d-8b17-60f7431abdb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85934564-7a2e-480d-8b17-60f7431abdb0")) {                    Plotly.newPlot(                        "85934564-7a2e-480d-8b17-60f7431abdb0",                        [{"alignmentgroup": "True", "hovertemplate": "variable=mean<br>seller_id=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "mean", "marker": {"color": "#636efa"}, "name": "mean", "offsetgroup": "mean", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["094ced053e257ae8cae57205592d6712", "0b1ca3ef18a63d7eb0c8897fa0849c08", "1c742ac33582852aaf3bcfbf5893abcf", "1cbd32d00d01bb8087a5eb088612fd9c", "28c7d8743fbc8679f484868cc0fcaefb", "2c2c9832d1bb38c5b0034a3b47d313ee", "2e7ea2aafec5835e781b21d6d1faf1f1", "2fa13c8bd5705d279f7ed5cc9ec61c68", "3d5d0dc7073a299e31fa718ce1bc00b6", "44ed138eca6214d572ce1d813fb0049b", "4867209cb29b56b92893d7bde3ce8012", "4a23adac87cf538689fa600d976f78b2", "4a82168aaef173cbb6e46ae88728f919", "4f0d637c1197fd65405ebd755ac9f86b", "516e7738bd8f735ac19a010ee5450d8d", "53088c75f948b48a7ece173ac17f0c12", "5670f4db5b62c43d542e1b2d56b0cf7c", "5e063e85d44b0f5c3e6ec3131103a57e", "698f5fa55a5f73d0740e9d9a773e8093", "6aa3928696eab49a19a466e665a649fd", "6bd503a8230299c9316fb0f726933927", "6ebf4eceee4dd9847201c82e77ef8123", "85ecf03781da592876b7844acc1b729f", "89a51f50b8095ea78d5768f34c13a76f", "8b181ee5518df84f18f4e1a43fe07923", "985c92cc412091f8529c12d7f23d3fef", "a63bfbaa882c8f4542891b4e2246cc7f", "a69aa24cec11168e7e39a3fbc727e925", "a7d0f8dd44f57ef6de7f7f02e3d82630", "ae45df84722b1d15c5f32b23a095746c", "b494891378bd8f4560abe576c52deacd", "bd4431c1a8dfa744b59e1e2a8bc99b9e", "c54679b132454625907c773d273d4126", "c70a353f02429c00775a46a75fb787da", "c70c1b0d8ca86052f45a432a38b73958", "ca4b77513ac2040591b0d8fae6958380", "ca7c6bd577e559472af1c699de9e764e", "ce4755084bc097113867e6454f8f5e52", "dace965ca58120f92f8d742a9fa1864b", "dbdd0ec73a4817971d962698f2fea022", "e116c7455dd26a4d8c3e92532583905f", "e9e446d01bd10a97a8ffcfc4a3a20cb2", "eb72802c83dc7547529c9546d1a9b8ef", "f22a247b79dd22ecd91dc8e3b2a1b07c", "f46490624488d3ff7ce78613913a7711"], "xaxis": "x", "y": [1.7272727272727273, 0.08333333333333333, 1.0, 0.9230769230769231, 0.10344827586206896, 0.3333333333333333, 0.07954545454545454, 0.6666666666666666, 1.411764705882353, 0.75, 0.05555555555555555, 0.018518518518518517, 0.031496062992125984, 0.16666666666666666, 14.0, 0.07142857142857142, 3.6666666666666665, -0.5, 6.0, 4.4, 0.05, 0.14285714285714285, 0.15384615384615385, 0.04932735426008968, 0.029411764705882353, null, 3.5, 0.05454545454545454, 2.0, 2.0, 0.8461538461538461, 0.30434782608695654, 1.6, 0.5, null, 0.22727272727272727, 0.2962962962962963, 1.0, 0.8, 1.7777777777777777, 0.2, 0.17391304347826086, 4.0, 0.14814814814814814, 2.1666666666666665], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "# ...

# %% [markdown]
# As we can see above, the mean sales per day is a better method to analyse this data. Some sales representatives may seem to sell less in the general terms, but they have a better sale/day ratio. The main sale representative, harshed as "c70c", is considered the first in both methods. Most of his transactions are won on the same day they begun, resulting in this "zero days" mean.

# %%
fig = px.scatter(health_beauty_days_sellers, x = "days_" , y = "count")
fig.show()
# Out:
# <div>                            <div id="b52bb505-d2bd-497e-a187-2167eb73f4ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b52bb505-d2bd-497e-a187-2167eb73f4ef")) {                    Plotly.newPlot(                        "b52bb505-d2bd-497e-a187-2167eb73f4ef",                        [{"hovertemplate": "days_=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [11, 12, 1, 13, 29, 3, 88, 6, 17, 4, 18, 162, 127, 12, 6, 42, 6, -2, 1, 5, 100, 7, 13, 223, 34, 0, 2, 55, 1, 6, 26, 23, 5, 12, 0, 66, 27, 1, 10, 9, 10, 23, 2, 54, 42], "xaxis": "x", "y": [19, 1, 1, 12, 3, 1, 7, 4, 24, 3, 1, 3, 4, 2, 84, 3, 22, 1, 6, 22, 5, 1, 2, 11, 1, 12, 7, 3, 2, 12, 22, 7, 8, 6, 338, 15, 8, 1, 8, 16, 2, 4, 8, 8, 91], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1 ...

# %% [markdown]
# Most of the sales are won on the very first day or within a week. However, some sales take more than 200 days to be confirmed, which is highly illogical.

# %% [markdown]
# # **Watches business segment.**

# %% [markdown]
# Down below, the same analysis is made on the Watches segment, which is the second most important on this dataframe.

# %%
watches = df_funnel_products.where(df_funnel_products['business_segment'] == 'watches').dropna(subset=["seller_id"])

# %%
watches.seller_id.unique().shape[0]
# Out:
# 3

# %% [markdown]
# There are only 3 sellers in this segment.

# %%
fig = px.histogram(watches.seller_id, x="seller_id").update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <div>                            <div id="caf40a1b-b4aa-4d51-8af5-526d06b5765e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caf40a1b-b4aa-4d51-8af5-526d06b5765e")) {                    Plotly.newPlot(                        "caf40a1b-b4aa-4d51-8af5-526d06b5765e",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "seller_id=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fca15225358621be4086e1eb0964", "7d13fc ...

# %%
watches_init_date    = watches.groupby(by = 'seller_id').min()['first_contact_date']
watches_oldest_seller= watches_init_date.sort_values(axis=0, ascending=True)
watches_oldest_seller
# Out:
# seller_id
# 7d13fca15225358621be4086e1eb0964   2018-01-22
# f9eda05b67bef472deaddbba84aca289   2018-02-26
# bce6a5ecf98e99fd2a8868b15c51f04b   2018-04-12
# Name: first_contact_date, dtype: datetime64[ns]

# %%
watches_won_date_max= watches.groupby(by = 'seller_id').max()['won_date']

# %%
watches_days_sellers = (watches_won_date_max-watches_init_date).apply(lambda d: d.days).to_frame(name='days_')

# %%
watches_count = watches.groupby(by = 'seller_id').count()['mql_id'].to_frame(name ='count')

# %%
watches_days_sellers = watches_days_sellers.merge(watches_count, on='seller_id', how='left')

# %%
watches_days_sellers['mean'] = watches_days_sellers['count'] /watches_days_sellers['days_']

# %%
watches_days_sellers.sort_values(axis=0, ascending=False,by='mean')
# Out:
#                                   days_  count       mean
# seller_id
# 7d13fca15225358621be4086e1eb0964     17    578  34.000000
# bce6a5ecf98e99fd2a8868b15c51f04b      1     15  15.000000
# f9eda05b67bef472deaddbba84aca289      9      1   0.111111

# %%
fig = px.bar(watches_days_sellers['mean'], x=watches_days_sellers.index, y=['mean']).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <div>                            <div id="ecb307e1-f034-41c6-a2b2-c53ff34ecf1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecb307e1-f034-41c6-a2b2-c53ff34ecf1c")) {                    Plotly.newPlot(                        "ecb307e1-f034-41c6-a2b2-c53ff34ecf1c",                        [{"alignmentgroup": "True", "hovertemplate": "variable=mean<br>seller_id=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "mean", "marker": {"color": "#636efa"}, "name": "mean", "offsetgroup": "mean", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["7d13fca15225358621be4086e1eb0964", "bce6a5ecf98e99fd2a8868b15c51f04b", "f9eda05b67bef472deaddbba84aca289"], "xaxis": "x", "y": [34.0, 15.0, 0.1111111111111111], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"co ...

# %% [markdown]
# In this case, the sales representatives which sold the most are also the ones with the best sales/day ratio.
